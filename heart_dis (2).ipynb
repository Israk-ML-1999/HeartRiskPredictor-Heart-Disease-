# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as splt
import seaborn

# %%
df = pd.read_csv('cardio_train.csv',sep=';')

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.shape
# Out:
# (70000, 13)

# %%
df.head(10)
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
# 5   8  21914       1     151    67.0    120     80            2     2      0
# 6   9  22113       1     157    93.0    130     80            3     1      0
# 7  12  22584       2     178    95.0    130     90            3     3      0
# 8  13  17668       1     158    71.0    110     70            1     1      0
# 9  14  19834       1     164    68.0    110     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# ...

# %%
value_counts = df['cardio'].value_counts()

# %%
value_counts
# Out:
# 0    35021
# 1    34979
# Name: cardio, dtype: int64

# %%
columns_to_drop = ['id']
df_dropped = df.drop(columns= columns_to_drop)

# %%
df_dropped
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is called 'df' and the column to visualize is 'column_name'
column_name_counts = df['cardio'].value_counts()

# Set custom colors
colors = ['green']

# Create a bar plot with custom colors
plt.bar(column_name_counts.index, column_name_counts.values, color=colors)

# Set labels and title
plt.xlabel('Column Values 1')
plt.ylabel('Count value 0')
plt.title('Cardio plote')

# Show the plot
plt.show()

# %%
seaborn .countplot (df_dropped['cardio'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cardio', ylabel='count'>

# %%
df_dropped.isnull().values.any()
# Out:
# False

# %%
df_dropped.isnull().sum()
# Out:
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
seaborn.countplot(x='gender',hue='cardio',data=df_dropped,palette='colorblind',edgecolor=seaborn.color_palette('dark',n_colors=1))
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
df_dropped['De_ye']=(df_dropped['age']/365).round(0)

# %%
df_dropped ['De_ye']
# Out:
# 0        50.0
# 1        55.0
# 2        52.0
# 3        48.0
# 4        48.0
#          ...
# 69995    53.0
# 69996    62.0
# 69997    52.0
# 69998    61.0
# 69999    56.0
# Name: De_ye, Length: 70000, dtype: float64

# %%
seaborn.countplot(x='De_ye',hue='cardio',data=df_dropped,palette='colorblind',edgecolor=seaborn.color_palette('dark',n_colors=1))
# Out:
# <AxesSubplot:xlabel='De_ye', ylabel='count'>

# %%
df_dropped.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   19468.865814      1.349571    164.359229     74.205690    128.817286
# std     2467.251667      0.476838      8.210126     14.395757    154.011419
# min    10798.000000      1.000000     55.000000     10.000000   -150.000000
# 25%    17664.000000      1.000000    159.000000     65.000000    120.000000
# 50%    19703.000000      1.000000    165.000000     72.000000    120.000000
# 75%    21327.000000      2.000000    170.000000     82.000000    140.000000
# max    23713.000000      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      96.630414      1.366871      1.226457      0.088129      0.053771
# ...

# %%
df_dropped.corr()
# Out:
#                   age    gender    height    weight     ap_hi     ap_lo  \
# age          1.000000 -0.022811 -0.081515  0.053684  0.020764  0.017647
# gender      -0.022811  1.000000  0.499033  0.155406  0.006005  0.015254
# height      -0.081515  0.499033  1.000000  0.290968  0.005488  0.006150
# weight       0.053684  0.155406  0.290968  1.000000  0.030702  0.043710
# ap_hi        0.020764  0.006005  0.005488  0.030702  1.000000  0.016086
# ap_lo        0.017647  0.015254  0.006150  0.043710  0.016086  1.000000
# cholesterol  0.154424 -0.035821 -0.050226  0.141768  0.023778  0.024019
# gluc         0.098703 -0.020491 -0.018595  0.106857  0.011841  0.010806
# smoke       -0.047633  0.338135  0.187989  0.067780 -0.000922  0.005186
# alco        -0.029723  0.170966  0.094419  0.067113  0.001408  0.010601
# active      -0.009927  0.005866 -0.006570 -0.016867 -0.000033  0.004780
# cardio       0.238159  0.008109 -0.010821  0.181660  0.054475  0.065719
# ...

# %%
df_dropped=df_dropped.drop(['De_ye'],axis=1)

# %%
df_dropped
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# ...

# %%
x=df_dropped.iloc[:,:-1]

# %%
x
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active
# 0         0       1
# ...

# %%
y=df_dropped.iloc[:,11]

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y, test_size=0.4,random_state=1)

# %%
xtrain
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 59047  16951       1     164    58.0    110     70            1     1      0
# 10266  20552       1     185    75.0    120     80            3     3      0
# 29871  21402       1     167    75.0    120     70            1     1      0
# 48946  20464       2     172   103.0    150     90            2     1      0
# 69336  21340       1     172    68.0    130     80            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 49100  21289       2     175    78.0    120     80            1     1      0
# 20609  19116       1     164    68.0    120     80            1     1      0
# 21440  18049       2     178    82.0    120     80            1     1      0
# 50057  21957       1     169    77.0    120     80            1     1      0
# 5192   20671       1     174    65.0    160     90            2     2      0
#
#        alco  active
# 59047     0       1
# ...

# %%
ytrain
# Out:
# 59047    0
# 10266    0
# 29871    0
# 48946    1
# 69336    1
#         ..
# 49100    1
# 20609    0
# 21440    0
# 50057    1
# 5192     1
# Name: cardio, Length: 42000, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

# Assuming you have already imported and preprocessed your training data (xtrain, ytrain)

# Create an instance of the RandomForestClassifier
rfc = RandomForestClassifier()

# %%
# Fit the model to the training data
rfc.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier()

# %%
rfc.score(xtest, ytest)
# Out:
# 0.719

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dcf =DecisionTreeClassifier()

# %%
dcf.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier()

# %%
dcf.score(xtest,ytest)
# Out:
# 0.6303928571428571

# %%
from sklearn import svm

# %%
clf = svm.SVC()

# %%
clf.fit(xtrain, ytrain)
# Out:
# SVC()

# %%
clf.score(xtest,ytest)
# Out:
# 0.6051071428571428
